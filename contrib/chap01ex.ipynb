# %%
# %matplotlib inline
import importer
import nsfg
df = nsfg.ReadFemPreg(dct_file='../code/2002FemPreg.dct',
                dat_file='../code/2002FemPreg.dat.gz')
df
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 9           7         2        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...

# %%
df.columns
# Out:
# Index([         u'caseid',        u'pregordr',       u'howpreg_n',
#              u'howpreg_p',        u'moscurrp',        u'nowprgdk',
#               u'pregend1',        u'pregend2',        u'nbrnaliv',
#               u'multbrth',
#        ...
#             u'laborfor_i',      u'religion_i',         u'metro_i',
#                u'basewgt', u'adj_mod_basewgt',        u'finalwgt',
#                 u'secu_p',            u'sest',         u'cmintvw',
#            u'totalwgt_lb'],
#       dtype='object', length=244)

# %%
import pandas as pd

df.to_csv('data/FemPreg.csv')

# %%
df = pd.read_csv('data/FemPreg.csv')

# %%
df.describe
# Out:
# <bound method DataFrame.describe of        Unnamed: 0  caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  \
# 0               0       1         1        NaN        NaN       NaN       NaN
# 1               1       1         2        NaN        NaN       NaN       NaN
# 2               2       2         1        NaN        NaN       NaN       NaN
# 3               3       2         2        NaN        NaN       NaN       NaN
# 4               4       2         3        NaN        NaN       NaN       NaN
# 5               5       6         1        NaN        NaN       NaN       NaN
# 6               6       6         2        NaN        NaN       NaN       NaN
# 7               7       6         3        NaN        NaN       NaN       NaN
# 8               8       7         1        NaN        NaN       NaN       NaN
# 9               9       7         2        NaN        NaN       NaN       NaN
# 10             10      12         1        NaN        NaN       NaN       NaN
# ...

# %%
pregordr = df['pregordr']
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
# 5        1
# 6        2
# 7        3
# 8        1
# 9        2
# 10       1
# 11       1
# 12       2
# 13       3
# 14       1
# 15       2
# 16       3
# 17       1
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       1
# 24       2
# 25       3
# 26       1
# 27       1
# 28       2
# 29       3
#         ..
# 13563    2
# 13564    3
# 13565    1
# 13566    1
# 13567    1
# 13568    2
# 13569    1
# 13570    2
# 13571    3
# 13572    4
# 13573    1
# 13574    2
# 13575    1
# 13576    1
# 13577    2
# 13578    1
# 13579    2
# 13580    1
# 13581    2
# 13582    3
# 13583    1
# 13584    2
# 13585    1
# 13586    2
# 13587    3
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, dtype: int64

# %%
outcome = df['outcome']
outcome_len = outcome.count()
outcome_len
# Out:
# 13593

# %%
outcome_live_len = df[df['outcome']!=1].outcome.count()
outcome_live_len
# Out:
# 4445

# %%
#Print value counts for birthord and compare to results published in the codebook
df.birthord.value_counts()
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %%
# Print value counts for prglngth and compare to results published in the codebook
df.prglngth.value_counts(sort=False)
# Out:
# 0       15
# 8      409
# 16      44
# 24      31
# 32     122
# 40    1120
# 48       7
# 1        9
# 9      594
# 17     253
# 25      15
# 33      50
# 41     591
# 2       78
# 10     137
# 18      17
# 26     117
# 34      60
# 42     328
# 50       2
# 3      151
# 11     202
# 19      34
# 27       8
# 35     357
# 43     148
# 4      412
# 12     170
# 20      18
# 28      38
# 36     329
# 44      46
# 5      181
# 13     446
# 21      37
# 29      23
# 37     457
# 45      10
# 6      543
# 14      29
# 22     147
# 30     198
# 38     609
# 46       1
# 7      175
# 15      39
# 23      12
# 31      29
# 39    4744
# 47       1
# Name: prglngth, dtype: int64

# %%
#Print value counts for agepreg and compare to results published in the codebook.
df.agepreg.value_counts(sort=True)
# Out:
# 22.75    100
# 21.75     92
# 20.00     91
# 18.83     90
# 21.25     90
# 21.83     87
# 18.91     85
# 20.91     83
# 21.58     83
# 22.25     83
# 20.41     82
# 20.50     82
# 21.41     81
# 23.08     81
# 19.50     81
# 24.25     81
# 20.83     80
# 18.58     80
# 20.08     80
# 18.41     79
# 24.83     79
# 19.33     78
# 23.25     78
# 19.66     78
# 21.33     77
# 23.16     76
# 20.75     76
# 19.58     76
# 21.00     76
# 19.83     75
#         ...
# 11.75      2
# 40.75      2
# 42.58      2
# 13.58      2
# 42.75      2
# 43.16      1
# 10.33      1
# 39.33      1
# 10.91      1
# 42.41      1
# 44.08      1
# 10.83      1
# 11.41      1
# 41.33      1
# 41.83      1
# 13.16      1
# 12.91      1
# 12.08      1
# 42.25      1
# 12.75      1
# 12.25      1
# 43.91      1
# 10.50      1
# 12.50      1
# 42.16      1
# 11.50      1
# 42.33      1
# 13.33      1
# 13.08      1
# 11.08      1
# Name: agepreg, dtype: int64

# %%
#Compute the mean birthweight.
df.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %%
#Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.
df['totalwgt_kg'] = df['totalwgt_lb']*0.453592
df.totalwgt_kg.mean()
# Out:
# 3.2956309433503437

# %%
#Use a boolean Series to select the records for the pregnancies that ended in live birth.
live = df[df.outcome == 1]
live.outcome.count()
# Out:
# 9148

# %%
#Count the number of live births with <tt>birthwgt_lb</tt> between 0 and 5 pounds (including both).  The result should be 1125.
live[(live.birthwgt_lb >= 0) & (live.birthwgt_lb <= 5)].shape[0]
# Out:
# 1125

# %%
#Count the number of live births with <tt>birthwgt_lb</tt> between 9 and 95 pounds (including both).  The result should be 798 
live[(live.birthwgt_lb >= 9) & (live.birthwgt_lb <= 95)].shape
# Out:
# (798, 246)

# %%
# Use <tt>birthord</tt> to select the records for first babies and others.  How many are there of each?
firsts = df[df['birthord']==1]
others = df[df['birthord']>1]
firsts.shape[0],others.shape[0]
# Out:
# (4413, 4735)

# %%
# Compute the mean weight for first babies and others.
firsts['totalwgt_lb'].mean()
# Out:
# 7.201094430437772

# %%
others.totalwgt_lb.mean()
# Out:
# 7.325855614973262

# %%
# Compute the mean prglngth for first babies and others. Compute the difference in means, expressed in hours
firsts['prglngth'].mean()
# Out:
# 38.60095173351461

# %%
others['prglngth'].mean()
# Out:
# 38.52291446673706

# %%
diff = firsts.prglngth.mean() - others.prglngth.mean()
diff
# Out:
# 0.07803726677754952

# %%
diff*7*24
# Out:
# 13.11026081862832

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import seaborn as sns

# %%
preg = nsfg.ReadFemPreg(dct_file='../code/2002FemPreg.dct',
                dat_file='../code/2002FemPreg.dat.gz')
live = preg[preg.outcome == 1]

# %%
sns.countplot(live.prglngth)

# %%
list(reversed(Counter(live.prglngth).items()))[0:10]
# Out:
# [(50, 2),
#  (48, 7),
#  (47, 1),
#  (46, 1),
#  (45, 10),
#  (44, 46),
#  (43, 148),
#  (42, 328),
#  (41, 587),
#  (40, 1116)]

# %%
Counter(live.prglngth).items()[0:10]
# Out:
# [(0, 1),
#  (4, 1),
#  (9, 1),
#  (13, 1),
#  (17, 2),
#  (18, 1),
#  (19, 1),
#  (20, 1),
#  (21, 2),
#  (22, 7)]

# %%
first_live =live[live.birthord == 1]
others_live =live[live.birthord != 1]

# %%
first_live.shape,others_live.shape,live.shape,preg.shape
# Out:
# ((4413, 244), (4735, 244), (9148, 244), (13593, 244))

# %%
plt.xlim(27,46)
plt.hist([first_live.prglngth,others_live.prglngth],bins=list(range(46)),color=['r','b'])
# Out:
# ([array([  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#            1.00000000e+00,   3.00000000e+00,   1.00000000e+00,
#            7.00000000e+00,   1.00000000e+00,   1.60000000e+01,
#            1.00000000e+00,   2.40000000e+01,   9.00000000e+00,
#            7.30000000e+01,   1.50000000e+01,   5.50000000e+01,
#            2.80000000e+01,   2.90000000e+01,   1.59000000e+02,
#            1.72000000e+02,   2.08000000e+02,   2.72000000e+02,
#            2.11400000e+03,   5.36000000e+02,   3.60000000e+02,
#            2.05000000e+02,   8.70000000e+01,   2.90000000e+01]),
# ...

# %%
live.prglngth.mean()
# Out:
# 38.56055968517709

# %%
live.prglngth.std()
# Out:
# 2.702343810070593

# %%
live.prglngth.var()
# Out:
# 7.302662067826851
